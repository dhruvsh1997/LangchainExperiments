# %%
# Install necessary libraries (updated for FAISS)
# !uv pip install scikit-learn matplotlib torch transformers sentence-transformers mteb faiss-cpu langchain langchain-community psutil
# Out:
# Streaming output truncated to the last 5000 lines.
# mteb       ------------------------------ 16.00 KiB/1.97 MiB
# langchain-community ------------------------------ 16.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 99.45 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 526.72 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 462.06 KiB/23.50 MiB
# faiss-cpu  ------------------------------ 456.56 KiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 492.34 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 576.53 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 603.39 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 653.86 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 477.11 KiB/346.60 MiB
# ⠸ Preparing packages... (6/27)
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 48.00 KiB/140.16 KiB
# fsspec     ------------------------------ 72.58 KiB/173.40 KiB
# xxhash     ------------------------------ 190.26 KiB/190.26 KiB
# datasets   ------------------------------ 158.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 237.27 KiB/863.02 KiB
# mteb       ------------------------------ 80.00 KiB/1.97 MiB
# langchain-community ------------------------------ 16.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 131.45 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 686.72 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 792.59 KiB/23.50 MiB
# faiss-cpu  ------------------------------ 776.56 KiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 492.34 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 576.53 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 603.39 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 717.86 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 685.11 KiB/346.60 MiB
# ⠸ Preparing packages... (6/27)
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 48.00 KiB/140.16 KiB
# fsspec     ------------------------------ 72.58 KiB/173.40 KiB
# datasets   ------------------------------ 158.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 237.27 KiB/863.02 KiB
# mteb       ------------------------------ 276.46 KiB/1.97 MiB
# langchain-community ------------------------------ 16.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 131.45 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 862.72 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 792.59 KiB/23.50 MiB
# faiss-cpu  ------------------------------ 776.56 KiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 492.34 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 735.02 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 732.29 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 829.86 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 844.97 KiB/346.60 MiB
# ⠸ Preparing packages... (6/27)
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 48.00 KiB/140.16 KiB
# fsspec     ------------------------------ 72.58 KiB/173.40 KiB
# datasets   ------------------------------ 222.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 237.27 KiB/863.02 KiB
# mteb       ------------------------------ 276.46 KiB/1.97 MiB
# langchain-community ------------------------------ 16.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 140.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 862.72 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 792.59 KiB/23.50 MiB
# faiss-cpu  ------------------------------ 776.56 KiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 499.16 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 735.02 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 732.29 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 829.86 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 844.97 KiB/346.60 MiB
# ⠸ Preparing packages... (6/27)
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 60.76 KiB/140.16 KiB
# fsspec     ------------------------------ 88.58 KiB/173.40 KiB
# datasets   ------------------------------ 222.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 237.27 KiB/863.02 KiB
# mteb       ------------------------------ 276.46 KiB/1.97 MiB
# langchain-community ------------------------------ 16.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 140.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 862.72 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 792.59 KiB/23.50 MiB
# faiss-cpu  ------------------------------ 776.56 KiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 828.34 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 735.02 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 732.29 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 829.86 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 844.97 KiB/346.60 MiB
# ⠸ Preparing packages... (6/27)
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 60.76 KiB/140.16 KiB
# fsspec     ------------------------------ 88.58 KiB/173.40 KiB
# datasets   ------------------------------ 222.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 237.27 KiB/863.02 KiB
# mteb       ------------------------------ 276.46 KiB/1.97 MiB
# langchain-community ------------------------------ 16.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 140.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 862.72 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 881.65 KiB/23.50 MiB
# faiss-cpu  ------------------------------ 904.46 KiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 828.34 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 863.02 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 844.29 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 957.86 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 844.97 KiB/346.60 MiB
# ⠸ Preparing packages... (6/27)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 92.76 KiB/140.16 KiB
# fsspec     ------------------------------ 104.58 KiB/173.40 KiB
# datasets   ------------------------------ 254.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 317.27 KiB/863.02 KiB
# mteb       ------------------------------ 294.08 KiB/1.97 MiB
# langchain-community ------------------------------ 32.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 140.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.15 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 931.57 KiB/23.50 MiB
# faiss-cpu  ------------------------------ 952.56 KiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1004.34 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 943.02 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1007.26 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.12 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.10 MiB/346.60 MiB
# ⠼ Preparing packages... (10/27)
# multiprocess ------------------------------ 92.76 KiB/140.16 KiB
# fsspec     ------------------------------ 128.00 KiB/173.40 KiB
# datasets   ------------------------------ 254.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 477.27 KiB/863.02 KiB
# mteb       ------------------------------ 336.00 KiB/1.97 MiB
# langchain-community ------------------------------ 32.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 172.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.15 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.15 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.07 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.13 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.06 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1007.26 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.12 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.10 MiB/346.60 MiB
# ⠼ Preparing packages... (10/27)
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 155.05 KiB/173.40 KiB
# datasets   ------------------------------ 254.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 477.27 KiB/863.02 KiB
# mteb       ------------------------------ 368.00 KiB/1.97 MiB
# langchain-community ------------------------------ 32.00 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 172.30 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.24 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.15 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.07 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.13 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.06 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1007.26 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.12 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.14 MiB/346.60 MiB
# ⠼ Preparing packages... (10/27)
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 171.05 KiB/173.40 KiB
# datasets   ------------------------------ 269.66 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 493.27 KiB/863.02 KiB
# mteb       ------------------------------ 368.00 KiB/1.97 MiB
# langchain-community ------------------------------ 60.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.23 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.32 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.18 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.16 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.27 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.20 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.14 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.28 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.26 MiB/346.60 MiB
# ⠼ Preparing packages... (10/27)
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# datasets   ------------------------------ 269.66 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 493.27 KiB/863.02 KiB
# mteb       ------------------------------ 368.00 KiB/1.97 MiB
# langchain-community ------------------------------ 60.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.23 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.32 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.21 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.16 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.27 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.20 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.14 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.28 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.26 MiB/346.60 MiB
# ⠼ Preparing packages... (10/27)
# datasets   ------------------------------ 317.66 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 557.27 KiB/863.02 KiB
# mteb       ------------------------------ 384.00 KiB/1.97 MiB
# langchain-community ------------------------------ 108.21 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.23 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.37 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.21 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.27 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.34 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.26 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.33 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.32 MiB/346.60 MiB
# ⠼ Preparing packages... (10/27)
# datasets   ------------------------------ 317.66 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 605.27 KiB/863.02 KiB
# mteb       ------------------------------ 463.67 KiB/1.97 MiB
# langchain-community ------------------------------ 108.21 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.31 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.54 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.41 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.43 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.34 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.26 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.39 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.32 MiB/346.60 MiB
# ⠼ Preparing packages... (10/27)
# datasets   ------------------------------ 334.10 KiB/514.89 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 653.27 KiB/863.02 KiB
# mteb       ------------------------------ 511.67 KiB/1.97 MiB
# langchain-community ------------------------------ 172.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.54 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.49 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.52 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.59 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.46 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.43 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.59 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.57 MiB/346.60 MiB
# ⠼ Preparing packages... (10/27)
# datasets   ------------------------------ 334.10 KiB/514.89 KiB
# mteb       ------------------------------ 511.67 KiB/1.97 MiB
# langchain-community ------------------------------ 172.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.54 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.49 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.52 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.59 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.46 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.43 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.59 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.57 MiB/346.60 MiB
# ⠴ Preparing packages... (13/27)
# datasets   ------------------------------ 350.10 KiB/514.89 KiB
# mteb       ------------------------------ 511.67 KiB/1.97 MiB
# langchain-community ------------------------------ 204.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.54 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.74 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.49 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.52 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.59 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.68 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.43 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.59 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.57 MiB/346.60 MiB
# ⠴ Preparing packages... (13/27)
# mteb       ------------------------------ 528.00 KiB/1.97 MiB
# langchain-community ------------------------------ 220.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.78 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.84 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.71 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.73 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.77 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.71 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.65 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.82 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.78 MiB/346.60 MiB
# ⠴ Preparing packages... (13/27)
# mteb       ------------------------------ 528.00 KiB/1.97 MiB
# langchain-community ------------------------------ 220.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.78 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.84 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.71 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.73 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.77 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.71 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.65 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.82 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.78 MiB/346.60 MiB
# ⠴ Preparing packages... (13/27)
# mteb       ------------------------------ 544.00 KiB/1.97 MiB
# langchain-community ------------------------------ 331.76 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.98 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.05 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.98 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 1.93 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.99 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.92 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.99 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.99 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.99 MiB/346.60 MiB
# ⠴ Preparing packages... (13/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 396.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.32 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.36 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.19 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.11 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.30 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.11 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.04 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.18 MiB/346.60 MiB
# ⠦ Preparing packages... (15/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 616.09 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.32 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.36 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.19 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.23 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.30 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.24 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.18 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.30 MiB/346.60 MiB
# ⠦ Preparing packages... (15/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 668.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.44 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.36 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.19 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.40 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.30 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.38 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.38 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.50 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.48 MiB/346.60 MiB
# ⠦ Preparing packages... (15/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 684.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.51 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.57 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.38 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.42 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.47 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.40 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.39 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.51 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.51 MiB/346.60 MiB
# ⠦ Preparing packages... (15/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 716.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.51 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.57 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.58 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.42 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.64 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.57 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.51 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.51 MiB/346.60 MiB
# ⠧ Preparing packages... (15/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 716.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.71 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.71 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.58 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.42 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.64 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.57 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.57 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.51 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.51 MiB/346.60 MiB
# ⠧ Preparing packages... (15/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 716.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.71 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.71 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.58 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.59 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.64 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.57 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.57 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.68 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.65 MiB/346.60 MiB
# ⠧ Preparing packages... (15/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 716.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.87 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.72 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.60 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.59 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.66 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.58 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.85 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.67 MiB/346.60 MiB
# ⠧ Preparing packages... (15/27)
# mteb       ------------------------------ 560.00 KiB/1.97 MiB
# langchain-community ------------------------------ 764.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.87 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.91 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.79 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.79 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.79 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.75 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.87 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.87 MiB/346.60 MiB
# ⠇ Preparing packages... (15/27)
# mteb       ------------------------------ 592.00 KiB/1.97 MiB
# langchain-community ------------------------------ 844.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.89 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.91 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.97 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.79 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.83 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.75 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.94 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.87 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.87 MiB/346.60 MiB
# ⠇ Preparing packages... (15/27)
# mteb       ------------------------------ 592.00 KiB/1.97 MiB
# langchain-community ------------------------------ 860.31 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.10 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.13 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.00 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.79 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.83 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.96 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.94 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.08 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.08 MiB/346.60 MiB
# ⠇ Preparing packages... (15/27)
# mteb       ------------------------------ 688.00 KiB/1.97 MiB
# langchain-community ------------------------------ 957.91 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.10 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.13 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.00 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.79 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.83 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.96 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.09 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.08 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.08 MiB/346.60 MiB
# ⠇ Preparing packages... (15/27)
# mteb       ------------------------------ 762.14 KiB/1.97 MiB
# langchain-community ------------------------------ 957.91 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.30 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.30 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.20 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 2.79 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.83 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.16 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.09 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.08 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.27 MiB/346.60 MiB
# ⠋ Preparing packages... (15/27)
# mteb       ------------------------------ 800.00 KiB/1.97 MiB
# langchain-community ------------------------------ 1.06 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.32 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.30 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.20 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 3.22 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.83 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.16 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.20 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.27 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.27 MiB/346.60 MiB
# ⠋ Preparing packages... (15/27)
# mteb       ------------------------------ 864.00 KiB/1.97 MiB
# langchain-community ------------------------------ 1.07 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.43 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.44 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.36 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 3.39 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.97 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.30 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.20 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.43 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.42 MiB/346.60 MiB
# ⠋ Preparing packages... (15/27)
# mteb       ------------------------------ 944.00 KiB/1.97 MiB
# langchain-community ------------------------------ 1.07 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.51 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.50 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.42 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 3.43 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 3.44 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.36 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.41 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.48 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.49 MiB/346.60 MiB
# ⠋ Preparing packages... (15/27)
# mteb       ------------------------------ 944.00 KiB/1.97 MiB
# langchain-community ------------------------------ 1.07 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.68 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.50 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.42 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 3.62 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 3.58 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.36 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.41 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.68 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.49 MiB/346.60 MiB
# ⠙ Preparing packages... (15/27)
# mteb       ------------------------------ 951.50 KiB/1.97 MiB
# langchain-community ------------------------------ 1.07 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.76 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.74 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.69 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 3.72 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 3.70 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.63 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.66 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.74 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.69 MiB/346.60 MiB
# ⠙ Preparing packages... (15/27)
# mteb       ------------------------------ 951.50 KiB/1.97 MiB
# langchain-community ------------------------------ 1.09 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.76 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.97 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.89 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 3.72 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 3.70 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.63 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.81 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.93 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.78 MiB/346.60 MiB
# ⠙ Preparing packages... (15/27)
# mteb       ------------------------------ 976.00 KiB/1.97 MiB
# langchain-community ------------------------------ 1.09 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.96 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.97 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.95 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 3.99 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 3.99 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.86 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.81 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.00 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.00 MiB/346.60 MiB
# ⠙ Preparing packages... (15/27)
# mteb       ------------------------------ 976.00 KiB/1.97 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.32 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.26 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.09 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 4.14 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 4.28 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.19 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.17 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.16 MiB/346.60 MiB
# ⠹ Preparing packages... (15/27)
# mteb       ------------------------------ 992.00 KiB/1.97 MiB
# langchain-community ------------------------------ 1.21 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.62 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.64 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.50 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 4.40 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 4.58 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.47 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.51 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.59 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.45 MiB/346.60 MiB
# ⠹ Preparing packages... (15/27)
# mteb       ------------------------------ 1007.89 KiB/1.97 MiB
# langchain-community ------------------------------ 1.25 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.73 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.64 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.55 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 4.59 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 4.58 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.47 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.51 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.59 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.62 MiB/346.60 MiB
# ⠹ Preparing packages... (15/27)
# mteb       ------------------------------ 1007.89 KiB/1.97 MiB
# langchain-community ------------------------------ 1.25 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.92 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.94 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.61 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 4.59 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 4.86 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.47 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.51 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.59 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.92 MiB/346.60 MiB
# ⠹ Preparing packages... (15/27)
# mteb       ------------------------------ 1007.89 KiB/1.97 MiB
# langchain-community ------------------------------ 1.25 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.92 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.94 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.83 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 4.85 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 4.86 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.75 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.79 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.84 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.92 MiB/346.60 MiB
# ⠸ Preparing packages... (15/27)
# mteb       ------------------------------ 1.02 MiB/1.97 MiB
# langchain-community ------------------------------ 1.37 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.93 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.95 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.84 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 4.87 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 4.86 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.99 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.01 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.09 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.92 MiB/346.60 MiB
# ⠸ Preparing packages... (15/27)
# mteb       ------------------------------ 1.02 MiB/1.97 MiB
# langchain-community ------------------------------ 1.37 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.21 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.25 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.07 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 5.21 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 5.12 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.99 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.01 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.09 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.24 MiB/346.60 MiB
# ⠸ Preparing packages... (15/27)
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.40 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.21 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.25 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.15 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 5.21 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 5.12 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.17 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.11 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.18 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.24 MiB/346.60 MiB
# ⠸ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.43 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.49 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.54 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.45 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 5.52 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 5.45 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.31 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.43 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.50 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.55 MiB/346.60 MiB
# ⠼ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.43 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.76 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.56 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.48 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 5.56 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 5.62 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.59 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.48 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.78 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.57 MiB/346.60 MiB
# ⠼ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.43 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.76 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.79 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.70 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 5.75 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 5.62 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.59 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.63 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.78 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.82 MiB/346.60 MiB
# ⠼ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.45 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.91 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.11 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.82 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 5.94 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 5.85 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.74 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.80 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.90 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.10 MiB/346.60 MiB
# ⠼ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.45 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 6.21 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.24 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.14 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 6.25 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 6.18 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.04 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.12 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.19 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.10 MiB/346.60 MiB
# ⠴ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.45 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 6.23 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.30 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.14 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 6.25 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 6.33 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.21 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.30 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.35 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.38 MiB/346.60 MiB
# ⠴ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.45 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 6.55 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.41 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.44 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 6.43 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 6.33 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.36 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.30 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.35 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.55 MiB/346.60 MiB
# ⠴ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.45 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 6.73 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.54 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.44 MiB/23.50 MiB
# faiss-cpu  ------------------------------ 6.77 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 6.66 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.36 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.44 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.63 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.57 MiB/346.60 MiB
# ⠦ Preparing packages... (15/27)
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.45 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 6.80 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.69 MiB/20.09 MiB
# ...
# nvidia-cufft-cu12 ------------------------------ 191.87 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 193.20 MiB/346.60 MiB
# ⠼ Preparing packages... (23/27)
# nvidia-cusparse-cu12 ------------------------------ 193.23 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 192.92 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 194.22 MiB/346.60 MiB
# ⠴ Preparing packages... (23/27)
# nvidia-cusparse-cu12 ------------------------------ 194.32 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 194.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.28 MiB/346.60 MiB
# ⠴ Preparing packages... (23/27)
# nvidia-cusparse-cu12 ------------------------------ 195.39 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 195.06 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 196.38 MiB/346.60 MiB
# ⠴ Preparing packages... (23/27)
# nvidia-cusparse-cu12 ------------------------------ 196.22 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 195.87 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 197.24 MiB/346.60 MiB
# ⠴ Preparing packages... (23/27)
# nvidia-cusparse-cu12 ------------------------------ 197.21 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 196.81 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 198.19 MiB/346.60 MiB
# ⠴ Preparing packages... (23/27)
# nvidia-cufft-cu12 ------------------------------ 197.51 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 198.98 MiB/346.60 MiB
# ⠦ Preparing packages... (24/27)
# nvidia-cufft-cu12 ------------------------------ 197.99 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 199.37 MiB/346.60 MiB
# ⠦ Preparing packages... (24/27)
# nvidia-cufft-cu12 ------------------------------ 199.37 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 200.85 MiB/346.60 MiB
# ⠦ Preparing packages... (24/27)
# nvidia-cufft-cu12 ------------------------------ 200.79 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 202.44 MiB/346.60 MiB
# ⠦ Preparing packages... (24/27)
# nvidia-cublas-cu12 ------------------------------ 203.34 MiB/346.60 MiB
# ⠦ Preparing packages... (24/27)
# nvidia-cublas-cu12 ------------------------------ 204.29 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 205.95 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 208.15 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 210.23 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 212.36 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 214.40 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 216.92 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 218.61 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 220.59 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 222.72 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 224.92 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 227.09 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 227.84 MiB/346.60 MiB
# ⠙ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 229.78 MiB/346.60 MiB
# ⠙ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 231.37 MiB/346.60 MiB
# ⠙ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 233.75 MiB/346.60 MiB
# ⠙ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 235.39 MiB/346.60 MiB
# ⠹ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 238.02 MiB/346.60 MiB
# ⠹ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 240.11 MiB/346.60 MiB
# ⠹ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 242.47 MiB/346.60 MiB
# ⠹ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 244.97 MiB/346.60 MiB
# ⠸ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 246.65 MiB/346.60 MiB
# ⠸ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 248.33 MiB/346.60 MiB
# ⠸ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 250.89 MiB/346.60 MiB
# ⠸ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 253.34 MiB/346.60 MiB
# ⠼ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 254.89 MiB/346.60 MiB
# ⠼ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 256.73 MiB/346.60 MiB
# ⠼ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 259.17 MiB/346.60 MiB
# ⠼ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 261.37 MiB/346.60 MiB
# ⠴ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 262.98 MiB/346.60 MiB
# ⠴ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 265.19 MiB/346.60 MiB
# ⠴ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 267.20 MiB/346.60 MiB
# ⠴ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 269.54 MiB/346.60 MiB
# ⠦ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 272.11 MiB/346.60 MiB
# ⠦ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 273.64 MiB/346.60 MiB
# ⠦ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 276.04 MiB/346.60 MiB
# ⠦ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 278.39 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 280.78 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 283.19 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 285.36 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 287.34 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 289.41 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 291.89 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 293.70 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 295.45 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 297.37 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 299.27 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 301.28 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 303.00 MiB/346.60 MiB
# ⠙ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 304.81 MiB/346.60 MiB
# ⠙ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 306.83 MiB/346.60 MiB
# ⠙ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 309.02 MiB/346.60 MiB
# ⠙ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 310.62 MiB/346.60 MiB
# ⠹ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 311.67 MiB/346.60 MiB
# ⠹ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 312.91 MiB/346.60 MiB
# ⠹ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 314.40 MiB/346.60 MiB
# ⠹ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 315.60 MiB/346.60 MiB
# ⠸ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 317.00 MiB/346.60 MiB
# ⠸ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 318.42 MiB/346.60 MiB
# ⠸ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 319.34 MiB/346.60 MiB
# ⠸ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 320.20 MiB/346.60 MiB
# ⠼ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 321.16 MiB/346.60 MiB
# ⠼ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 322.48 MiB/346.60 MiB
# ⠼ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 323.85 MiB/346.60 MiB
# ⠼ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 324.85 MiB/346.60 MiB
# ⠴ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 325.68 MiB/346.60 MiB
# ⠴ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 326.61 MiB/346.60 MiB
# ⠴ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 327.94 MiB/346.60 MiB
# ⠴ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 329.35 MiB/346.60 MiB
# ⠦ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 330.32 MiB/346.60 MiB
# ⠦ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 331.08 MiB/346.60 MiB
# ⠦ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 332.22 MiB/346.60 MiB
# ⠦ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 333.46 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 334.81 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 336.20 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 337.49 MiB/346.60 MiB
# ⠧ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 338.87 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 340.27 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 341.65 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 343.07 MiB/346.60 MiB
# ⠇ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 344.44 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# nvidia-cublas-cu12 ------------------------------ 345.72 MiB/346.60 MiB
# ⠋ Preparing packages... (25/27)
# ⠋ Preparing packages... (25/27)
# ⠋ Preparing packages... (25/27)
# ⠋ Preparing packages... (25/27)
# ⠙ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠙ Preparing packages... (26/27)
# ⠹ Preparing packages... (26/27)
# ⠸ Preparing packages... (26/27)
# ⠼ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠴ Preparing packages... (26/27)
# ⠦ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠧ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠇ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# ⠋ Preparing packages... (26/27)
# Prepared 27 packages in 41.44s
# Uninstalled 11 packages in 36ms
# Installed 27 packages in 63ms
#  + dataclasses-json==0.6.7
#  + datasets==2.21.0
#  + dill==0.3.8
#  + eval-type-backport==0.2.2
#  + faiss-cpu==1.10.0
#  - fsspec==2025.3.2
#  + fsspec==2024.6.1
#  + httpx-sse==0.4.0
#  + langchain-community==0.3.21
#  + marshmallow==3.26.1
#  + mteb==1.38.1
#  + multiprocess==0.70.16
#  + mypy-extensions==1.1.0
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + pydantic-settings==2.9.1
#  + python-dotenv==1.1.0
#  + pytrec-eval-terrier==0.5.7
#  + typing-inspect==0.9.0
#  + xxhash==3.5.0

# %%
# Import libraries (updated vector store import)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import ndcg_score
import nltk
import re
import torch
from sentence_transformers import SentenceTransformer
from mteb import MTEB
import pandas as pd
from langchain.docstore.document import Document
from langchain.vectorstores import FAISS  # Changed import
from langchain.embeddings import HuggingFaceEmbeddings  # Updated embedding class
import time
import psutil
import shutil

# Download NLTK resources (unchanged)
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Text cleaning function (unchanged)
def simple_clean(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
# Data loading (unchanged)
df = pd.read_excel('/content/synthetic_resume_summaries (1).xlsx')
df.head()
# Out:
#                                                 text  \
# 0  Medical Advisor - General Medicines (Diabetes)...
# 1  linkedin.com/in/hafsah09/\n\nSUMMARY ,\n* Over...
# 2  'o\n\n+\n\nSummary ,\nI have a very positive a...
# 3  BRIDGETTE\nWENG\n2007\n\nPROFILE\n\nExtremely ...
# 4  Professional Summary ,\nA highly organised, mo...
#
#                                              summary
# 0  **Medical Advisor** with over 15 years of expe...
# 1  **Digital Product Management Professional** wi...
# 2  **Accountant** with experience in financial ma...
# 3  **Medical Assistant** with hands-on experience...
# 4  **Aspiring Legal Professional** with a strong ...

# %%
texts = df["text"].tolist()
summaries = df["summary"].tolist()
N = len(texts)

# Data cleaning (unchanged)
texts_clean = [simple_clean(text) for text in texts]
summaries_clean = [simple_clean(str(summary)) for summary in summaries]

# Document creation (unchanged)
docs = [Document(page_content=text, metadata={"id": i}) for i, text in enumerate(texts_clean)]

# %%
# Embedding setup (updated to HuggingFaceEmbeddings)
model_name = "multi-qa-mpnet-base-dot-v1"
embedding_function = HuggingFaceEmbeddings(model_name=model_name)
# Out:
# <ipython-input-6-58611bba2be3>:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_function = HuggingFaceEmbeddings(model_name=model_name)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/8.71k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# FAISS Ingestion with persistence (modified section)
start_time = time.time()
vectorstore = FAISS.from_documents(
    documents=docs,
    embedding=embedding_function
)
# Save FAISS index to disk
vectorstore.save_local("faiss_index")
ingestion_time = time.time() - start_time
print(f"Ingestion time: {ingestion_time} seconds")
# Out:
# Ingestion time: 35.73035407066345 seconds

# %%
# Retriever setup (unchanged interface)
retriever = vectorstore.as_retriever(search_kwargs={"k": 1})

# %%
# Performance metrics (unchanged collection logic)
latencies = []
recalls = []

for i, query in enumerate(summaries_clean):
    start_time = time.time()
    retrieved_docs = retriever.get_relevant_documents(query)
    latency = time.time() - start_time
    latencies.append(latency)

    retrieved_ids = [doc.metadata["id"] for doc in retrieved_docs]
    correct_id = i
    recalls.append(1 if correct_id in retrieved_ids else 0)

# Calculate metrics (unchanged)
average_recall = sum(recalls) / len(recalls)
print(f"Average recall@1: {average_recall}")
# Out:
# <ipython-input-9-94dea75f0b51>:7: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   retrieved_docs = retriever.get_relevant_documents(query)
# Average recall@1: 0.703

# %%
average_latency = sum(latencies) / len(latencies)
print(f"Average latency: {average_latency} seconds")
# Out:
# Average latency: 0.015947448968887327 seconds

# %%
total_queries = len(summaries_clean)
total_time = sum(latencies)
QPS = total_queries / total_time if total_time > 0 else 0
print(f"QPS: {QPS}")
# Out:
# QPS: 62.705953908424455

# %%
# Memory usage (unchanged)
memory_usage = psutil.virtual_memory().used / (1024 ** 3)
print(f"Memory usage: {memory_usage} GB")
# Out:
# Memory usage: 2.261425018310547 GB

# %%
# Disk usage measurement updated for FAISS
disk_usage = shutil.disk_usage('./faiss_index').used / (1024 ** 3)
print(f"Disk usage for faiss_index: {disk_usage} GB")
# Out:
# Disk usage for faiss_index: 40.1653938293457 GB
