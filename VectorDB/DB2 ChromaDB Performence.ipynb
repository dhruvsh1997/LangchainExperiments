# %%
# Install necessary libraries (run once per Colab session)
# !uv pip install scikit-learn matplotlib torch transformers sentence-transformers mteb chromadb langchain  langchain-community psutil
# Out:
# Streaming output truncated to the last 5000 lines.
# kubernetes ------------------------------ 1.34 MiB/1.90 MiB
# mteb       ------------------------------ 1.01 MiB/1.97 MiB
# langchain-community ------------------------------ 1006.90 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 7.89 MiB/13.17 MiB
# onnxruntime ------------------------------ 7.94 MiB/15.26 MiB
# chromadb   ------------------------------ 8.05 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.98 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 7.95 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.01 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.96 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 7.99 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.75 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.74 MiB/346.60 MiB
# ⠹ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.34 MiB/1.90 MiB
# mteb       ------------------------------ 1.01 MiB/1.97 MiB
# langchain-community ------------------------------ 1022.90 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 7.89 MiB/13.17 MiB
# onnxruntime ------------------------------ 7.95 MiB/15.26 MiB
# chromadb   ------------------------------ 8.12 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.98 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.11 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.01 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.96 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 7.99 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.95 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.95 MiB/346.60 MiB
# ⠹ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.35 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1022.90 KiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.08 MiB/13.17 MiB
# onnxruntime ------------------------------ 7.95 MiB/15.26 MiB
# chromadb   ------------------------------ 8.32 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.17 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.14 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.17 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.97 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.96 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.96 MiB/346.60 MiB
# ⠹ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.35 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.01 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.08 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.14 MiB/15.26 MiB
# chromadb   ------------------------------ 8.32 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.17 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.30 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.17 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.17 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.10 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.12 MiB/346.60 MiB
# ⠸ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.35 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.01 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.09 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.15 MiB/15.26 MiB
# chromadb   ------------------------------ 8.35 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.34 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.31 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.37 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.19 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.39 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.14 MiB/346.60 MiB
# ⠸ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.35 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.01 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.10 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.34 MiB/15.26 MiB
# chromadb   ------------------------------ 8.50 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.34 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.48 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.37 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.36 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.39 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.33 MiB/346.60 MiB
# ⠸ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.35 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.03 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.43 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.40 MiB/15.26 MiB
# chromadb   ------------------------------ 8.56 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.40 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.62 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.59 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.56 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.44 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.38 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.37 MiB/346.60 MiB
# ⠸ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.37 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.03 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.49 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.59 MiB/15.26 MiB
# chromadb   ------------------------------ 8.72 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.54 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.67 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.59 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.62 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.62 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.54 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.55 MiB/346.60 MiB
# ⠼ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.37 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.03 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.49 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.73 MiB/15.26 MiB
# chromadb   ------------------------------ 8.92 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.59 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.70 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.62 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.62 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.69 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.58 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.55 MiB/346.60 MiB
# ⠼ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.37 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.03 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.49 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.73 MiB/15.26 MiB
# chromadb   ------------------------------ 8.92 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.74 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.85 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.76 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.76 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.76 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.56 MiB/346.60 MiB
# ⠼ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.37 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.05 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.61 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.73 MiB/15.26 MiB
# chromadb   ------------------------------ 8.92 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.89 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.83 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.83 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.83 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.77 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.72 MiB/346.60 MiB
# ⠼ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.37 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.05 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.67 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.77 MiB/15.26 MiB
# chromadb   ------------------------------ 9.12 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.00 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.83 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.83 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.83 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.77 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.72 MiB/346.60 MiB
# ⠴ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.37 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.05 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.68 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.91 MiB/15.26 MiB
# chromadb   ------------------------------ 9.12 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.93 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.06 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.95 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.96 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.83 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.89 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.86 MiB/346.60 MiB
# ⠴ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.38 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.05 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.89 MiB/13.17 MiB
# onnxruntime ------------------------------ 8.97 MiB/15.26 MiB
# chromadb   ------------------------------ 9.19 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.15 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.11 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.01 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.01 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.01 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.96 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.92 MiB/346.60 MiB
# ⠴ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.38 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.05 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.01 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.00 MiB/15.26 MiB
# chromadb   ------------------------------ 9.19 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.15 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.25 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.13 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.17 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.15 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.11 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.92 MiB/346.60 MiB
# ⠴ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.38 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.05 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.06 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.13 MiB/15.26 MiB
# chromadb   ------------------------------ 9.40 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.35 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.34 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.20 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.21 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.23 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.17 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.12 MiB/346.60 MiB
# ⠦ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.38 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.06 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.18 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.28 MiB/15.26 MiB
# chromadb   ------------------------------ 9.55 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.35 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.45 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.34 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.35 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.37 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.30 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.26 MiB/346.60 MiB
# ⠦ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.40 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.06 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.38 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.32 MiB/15.26 MiB
# chromadb   ------------------------------ 9.61 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.38 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.49 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.54 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.42 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.43 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.36 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.46 MiB/346.60 MiB
# ⠦ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.40 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.08 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.45 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.46 MiB/15.26 MiB
# chromadb   ------------------------------ 9.75 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.52 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.68 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.62 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.56 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.64 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.50 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.48 MiB/346.60 MiB
# ⠦ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.40 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.08 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.45 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.50 MiB/15.26 MiB
# chromadb   ------------------------------ 9.97 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.74 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.81 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.74 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.75 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.78 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.70 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.65 MiB/346.60 MiB
# ⠧ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.40 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.08 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.75 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.65 MiB/15.26 MiB
# chromadb   ------------------------------ 9.97 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.74 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.81 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.74 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.98 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.78 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.70 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.82 MiB/346.60 MiB
# ⠧ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.40 MiB/1.90 MiB
# mteb       ------------------------------ 1.03 MiB/1.97 MiB
# langchain-community ------------------------------ 1.09 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.81 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.82 MiB/15.26 MiB
# chromadb   ------------------------------ 10.18 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.96 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.01 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.74 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.98 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.98 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.89 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.82 MiB/346.60 MiB
# ⠧ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.42 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.11 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.81 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.82 MiB/15.26 MiB
# chromadb   ------------------------------ 10.36 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.96 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.01 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.92 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.98 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.98 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.05 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.04 MiB/346.60 MiB
# ⠧ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.42 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.11 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.01 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.82 MiB/15.26 MiB
# chromadb   ------------------------------ 10.39 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.96 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.20 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.14 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.07 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.98 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.05 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.04 MiB/346.60 MiB
# ⠇ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.42 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.11 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.01 MiB/13.17 MiB
# onnxruntime ------------------------------ 9.92 MiB/15.26 MiB
# chromadb   ------------------------------ 10.39 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.16 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.20 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.14 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.20 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.98 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.05 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.04 MiB/346.60 MiB
# ⠇ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.42 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.12 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.03 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.02 MiB/15.26 MiB
# chromadb   ------------------------------ 10.41 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.16 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.21 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.19 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.20 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.18 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.09 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.04 MiB/346.60 MiB
# ⠇ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.42 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.12 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.03 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.02 MiB/15.26 MiB
# chromadb   ------------------------------ 10.41 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.35 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.41 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.33 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.43 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.09 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.26 MiB/346.60 MiB
# ⠇ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.12 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.22 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.23 MiB/15.26 MiB
# chromadb   ------------------------------ 10.59 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.36 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.43 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.39 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.45 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.41 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.30 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.37 MiB/346.60 MiB
# ⠋ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.12 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.22 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.34 MiB/15.26 MiB
# chromadb   ------------------------------ 10.67 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.43 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.52 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.47 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.52 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.39 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.37 MiB/346.60 MiB
# ⠋ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.12 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.30 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.34 MiB/15.26 MiB
# chromadb   ------------------------------ 10.67 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.43 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.62 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.47 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.52 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.58 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.37 MiB/346.60 MiB
# ⠋ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.12 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.42 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.34 MiB/15.26 MiB
# chromadb   ------------------------------ 10.67 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.60 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.70 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.47 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.71 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.58 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.37 MiB/346.60 MiB
# ⠋ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.05 MiB/1.97 MiB
# langchain-community ------------------------------ 1.12 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.46 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.51 MiB/15.26 MiB
# chromadb   ------------------------------ 10.84 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.63 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.74 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.63 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.71 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.66 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.62 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.52 MiB/346.60 MiB
# ⠙ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.06 MiB/1.97 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.51 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.72 MiB/15.26 MiB
# chromadb   ------------------------------ 10.89 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.63 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.88 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.69 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.76 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.71 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.62 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.57 MiB/346.60 MiB
# ⠙ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.06 MiB/1.97 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.51 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.72 MiB/15.26 MiB
# chromadb   ------------------------------ 11.07 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.77 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.88 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.86 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.76 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.86 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.80 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.73 MiB/346.60 MiB
# ⠙ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.06 MiB/1.97 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.65 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.72 MiB/15.26 MiB
# chromadb   ------------------------------ 11.07 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.80 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.90 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.86 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.94 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.86 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.80 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.73 MiB/346.60 MiB
# ⠙ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.06 MiB/1.97 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.65 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.72 MiB/15.26 MiB
# chromadb   ------------------------------ 11.07 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.03 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.08 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.05 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.94 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.86 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.04 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.89 MiB/346.60 MiB
# ⠹ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# mteb       ------------------------------ 1.06 MiB/1.97 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.85 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.93 MiB/15.26 MiB
# chromadb   ------------------------------ 11.27 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.03 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.08 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.05 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.96 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.05 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.04 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.90 MiB/346.60 MiB
# ⠹ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
# mteb       ------------------------------ 1.06 MiB/1.97 MiB
# langchain-community ------------------------------ 1.16 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.85 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.93 MiB/15.26 MiB
# chromadb   ------------------------------ 11.43 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.03 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.08 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.05 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.17 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.05 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.04 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.90 MiB/346.60 MiB
# ⠹ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
# mteb       ------------------------------ 1.06 MiB/1.97 MiB
# langchain-community ------------------------------ 1.16 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.85 MiB/13.17 MiB
# onnxruntime ------------------------------ 10.93 MiB/15.26 MiB
# chromadb   ------------------------------ 11.47 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.14 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.08 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.24 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.40 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.28 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.04 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.90 MiB/346.60 MiB
# ⠹ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
# mteb       ------------------------------ 1.06 MiB/1.97 MiB
# langchain-community ------------------------------ 1.16 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.86 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.15 MiB/15.26 MiB
# chromadb   ------------------------------ 11.47 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.25 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.08 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.24 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.40 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.28 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.04 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.90 MiB/346.60 MiB
# ⠸ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# mteb       ------------------------------ 1.08 MiB/1.97 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.05 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.27 MiB/15.26 MiB
# chromadb   ------------------------------ 11.47 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.25 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.32 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.24 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.40 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.28 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.24 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.13 MiB/346.60 MiB
# ⠸ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# mteb       ------------------------------ 1.08 MiB/1.97 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.20 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.31 MiB/15.26 MiB
# chromadb   ------------------------------ 11.63 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.39 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.44 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.46 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.52 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.42 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.38 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.24 MiB/346.60 MiB
# ⠸ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# mteb       ------------------------------ 1.08 MiB/1.97 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.28 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.37 MiB/15.26 MiB
# chromadb   ------------------------------ 11.71 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.47 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.52 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.52 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.61 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.46 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.33 MiB/346.60 MiB
# ⠸ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# mteb       ------------------------------ 1.08 MiB/1.97 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.41 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.37 MiB/15.26 MiB
# chromadb   ------------------------------ 11.71 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.47 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.52 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.52 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.61 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.46 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.57 MiB/346.60 MiB
# ⠼ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# mteb       ------------------------------ 1.08 MiB/1.97 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.50 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.37 MiB/15.26 MiB
# chromadb   ------------------------------ 11.71 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.47 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.52 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.52 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.85 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.46 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.57 MiB/346.60 MiB
# ⠼ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# mteb       ------------------------------ 1.08 MiB/1.97 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.50 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.57 MiB/15.26 MiB
# chromadb   ------------------------------ 11.71 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.67 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.52 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.52 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.85 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.57 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.57 MiB/346.60 MiB
# ⠼ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# mteb       ------------------------------ 1.08 MiB/1.97 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.50 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.57 MiB/15.26 MiB
# chromadb   ------------------------------ 11.71 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.67 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.77 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.53 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.85 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.71 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.67 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.57 MiB/346.60 MiB
# ⠼ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.48 MiB/1.90 MiB
# mteb       ------------------------------ 1.09 MiB/1.97 MiB
# langchain-community ------------------------------ 1.20 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.50 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.57 MiB/15.26 MiB
# chromadb   ------------------------------ 11.91 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.67 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.77 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.71 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.85 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.71 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.67 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.57 MiB/346.60 MiB
# ⠴ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.49 MiB/1.90 MiB
# mteb       ------------------------------ 1.09 MiB/1.97 MiB
# langchain-community ------------------------------ 1.22 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.50 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.57 MiB/15.26 MiB
# chromadb   ------------------------------ 11.91 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.67 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.77 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.71 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.85 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.71 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.57 MiB/346.60 MiB
# ⠴ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.49 MiB/1.90 MiB
# mteb       ------------------------------ 1.09 MiB/1.97 MiB
# langchain-community ------------------------------ 1.22 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.69 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.57 MiB/15.26 MiB
# chromadb   ------------------------------ 11.99 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.67 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.77 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.71 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.85 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.89 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.75 MiB/346.60 MiB
# ⠴ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.49 MiB/1.90 MiB
# mteb       ------------------------------ 1.09 MiB/1.97 MiB
# langchain-community ------------------------------ 1.22 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.69 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.76 MiB/15.26 MiB
# chromadb   ------------------------------ 12.11 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.86 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.91 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.71 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.85 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.89 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.75 MiB/346.60 MiB
# ⠴ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.49 MiB/1.90 MiB
# mteb       ------------------------------ 1.09 MiB/1.97 MiB
# langchain-community ------------------------------ 1.22 MiB/2.41 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.69 MiB/13.17 MiB
# onnxruntime ------------------------------ 11.76 MiB/15.26 MiB
# chromadb   ------------------------------ 12.16 MiB/17.44 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 11.86 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11.99 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.91 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 12.04 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 11.89 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 11.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 11.75 MiB/346.60 MiB
# ⠦ Preparing packages... (42/56)
# kubernetes ------------------------------ 1.49 MiB/1.90 MiB
# mteb       ------------------------------ 1.09 MiB/1.97 MiB
# ...
# nvidia-cublas-cu12 ------------------------------ 192.32 MiB/346.60 MiB
# ⠹ Preparing packages... (52/56)
# nvidia-cusparse-cu12 ------------------------------ 193.66 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 193.51 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 193.18 MiB/346.60 MiB
# ⠸ Preparing packages... (52/56)
# nvidia-cusparse-cu12 ------------------------------ 194.60 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 194.46 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 194.10 MiB/346.60 MiB
# ⠸ Preparing packages... (52/56)
# nvidia-cusparse-cu12 ------------------------------ 195.60 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 195.44 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 194.97 MiB/346.60 MiB
# ⠸ Preparing packages... (52/56)
# nvidia-cusparse-cu12 ------------------------------ 196.55 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 196.39 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.81 MiB/346.60 MiB
# ⠸ Preparing packages... (52/56)
# nvidia-cusparse-cu12 ------------------------------ 196.97 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 196.79 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 196.24 MiB/346.60 MiB
# ⠼ Preparing packages... (52/56)
# nvidia-cusparse-cu12 ------------------------------ 197.40 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 197.39 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 196.78 MiB/346.60 MiB
# ⠼ Preparing packages... (52/56)
# nvidia-cufft-cu12 ------------------------------ 197.86 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 197.35 MiB/346.60 MiB
# ⠼ Preparing packages... (52/56)
# nvidia-cufft-cu12 ------------------------------ 198.12 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 197.78 MiB/346.60 MiB
# ⠼ Preparing packages... (52/56)
# nvidia-cufft-cu12 ------------------------------ 199.27 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 198.90 MiB/346.60 MiB
# ⠼ Preparing packages... (52/56)
# nvidia-cufft-cu12 ------------------------------ 200.14 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 199.84 MiB/346.60 MiB
# ⠴ Preparing packages... (53/56)
# nvidia-cufft-cu12 ------------------------------ 201.29 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 200.95 MiB/346.60 MiB
# ⠴ Preparing packages... (53/56)
# nvidia-cufft-cu12 ------------------------------ 201.66 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 202.27 MiB/346.60 MiB
# ⠴ Preparing packages... (53/56)
# nvidia-cublas-cu12 ------------------------------ 202.57 MiB/346.60 MiB
# ⠴ Preparing packages... (53/56)
# nvidia-cublas-cu12 ------------------------------ 203.81 MiB/346.60 MiB
# ⠴ Preparing packages... (53/56)
# nvidia-cublas-cu12 ------------------------------ 204.83 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 206.55 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 207.50 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 208.69 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 210.28 MiB/346.60 MiB
# ⠧ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 211.78 MiB/346.60 MiB
# ⠧ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 213.10 MiB/346.60 MiB
# ⠧ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 214.55 MiB/346.60 MiB
# ⠧ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 217.03 MiB/346.60 MiB
# ⠇ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 219.12 MiB/346.60 MiB
# ⠇ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 220.70 MiB/346.60 MiB
# ⠇ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 222.64 MiB/346.60 MiB
# ⠇ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 224.95 MiB/346.60 MiB
# ⠋ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 227.00 MiB/346.60 MiB
# ⠋ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 229.62 MiB/346.60 MiB
# ⠋ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 231.53 MiB/346.60 MiB
# ⠋ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 233.77 MiB/346.60 MiB
# ⠙ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 235.36 MiB/346.60 MiB
# ⠙ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 238.39 MiB/346.60 MiB
# ⠙ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 240.71 MiB/346.60 MiB
# ⠙ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 242.52 MiB/346.60 MiB
# ⠹ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 244.37 MiB/346.60 MiB
# ⠹ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 246.67 MiB/346.60 MiB
# ⠹ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 249.05 MiB/346.60 MiB
# ⠹ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 250.86 MiB/346.60 MiB
# ⠸ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 252.50 MiB/346.60 MiB
# ⠸ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 254.36 MiB/346.60 MiB
# ⠸ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 256.40 MiB/346.60 MiB
# ⠸ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 258.95 MiB/346.60 MiB
# ⠼ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 261.35 MiB/346.60 MiB
# ⠼ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 262.99 MiB/346.60 MiB
# ⠼ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 263.89 MiB/346.60 MiB
# ⠼ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 264.92 MiB/346.60 MiB
# ⠴ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 266.97 MiB/346.60 MiB
# ⠴ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 269.03 MiB/346.60 MiB
# ⠴ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 270.32 MiB/346.60 MiB
# ⠴ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 272.55 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 274.40 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 276.40 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 278.43 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 280.17 MiB/346.60 MiB
# ⠧ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 282.64 MiB/346.60 MiB
# ⠧ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 284.72 MiB/346.60 MiB
# ⠧ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 286.21 MiB/346.60 MiB
# ⠧ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 287.72 MiB/346.60 MiB
# ⠇ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 289.94 MiB/346.60 MiB
# ⠇ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 291.39 MiB/346.60 MiB
# ⠇ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 293.50 MiB/346.60 MiB
# ⠇ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 295.80 MiB/346.60 MiB
# ⠋ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 296.56 MiB/346.60 MiB
# ⠋ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 298.12 MiB/346.60 MiB
# ⠋ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 300.14 MiB/346.60 MiB
# ⠋ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 301.61 MiB/346.60 MiB
# ⠙ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 303.07 MiB/346.60 MiB
# ⠙ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 304.92 MiB/346.60 MiB
# ⠙ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 306.92 MiB/346.60 MiB
# ⠙ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 308.94 MiB/346.60 MiB
# ⠹ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 311.58 MiB/346.60 MiB
# ⠹ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 313.80 MiB/346.60 MiB
# ⠹ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 316.23 MiB/346.60 MiB
# ⠹ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 318.65 MiB/346.60 MiB
# ⠸ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 320.73 MiB/346.60 MiB
# ⠸ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 323.60 MiB/346.60 MiB
# ⠸ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 324.95 MiB/346.60 MiB
# ⠸ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 327.53 MiB/346.60 MiB
# ⠼ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 330.27 MiB/346.60 MiB
# ⠼ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 332.38 MiB/346.60 MiB
# ⠼ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 334.05 MiB/346.60 MiB
# ⠼ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 336.47 MiB/346.60 MiB
# ⠴ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 338.94 MiB/346.60 MiB
# ⠴ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 341.76 MiB/346.60 MiB
# ⠴ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 343.87 MiB/346.60 MiB
# ⠴ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 346.31 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# nvidia-cublas-cu12 ------------------------------ 346.60 MiB/346.60 MiB
# ⠦ Preparing packages... (54/56)
# ⠦ Preparing packages... (54/56)
# ⠦ Preparing packages... (54/56)
# ⠦ Preparing packages... (54/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠧ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠇ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠋ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠙ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠹ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠸ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠼ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠴ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# ⠦ Preparing packages... (55/56)
# Prepared 56 packages in 49.87s
# Uninstalled 11 packages in 39ms
# Installed 56 packages in 108ms
#  + asgiref==3.8.1
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + build==1.2.2.post1
#  + chroma-hnswlib==0.7.6
#  + chromadb==1.0.6
#  + coloredlogs==15.0.1
#  + dataclasses-json==0.6.7
#  + datasets==2.21.0
#  + dill==0.3.8
#  + durationpy==0.9
#  + eval-type-backport==0.2.2
#  + fastapi==0.115.9
#  - fsspec==2025.3.2
#  + fsspec==2024.6.1
#  + httptools==0.6.4
#  + httpx-sse==0.4.0
#  + humanfriendly==10.0
#  + kubernetes==32.0.1
#  + langchain-community==0.3.21
#  + marshmallow==3.26.1
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mteb==1.38.1
#  + multiprocess==0.70.16
#  + mypy-extensions==1.1.0
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + onnxruntime==1.21.1
#  + opentelemetry-exporter-otlp-proto-common==1.32.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.32.1
#  + opentelemetry-instrumentation==0.53b1
#  + opentelemetry-instrumentation-asgi==0.53b1
#  + opentelemetry-instrumentation-fastapi==0.53b1
#  + opentelemetry-proto==1.32.1
#  + opentelemetry-util-http==0.53b1
#  + overrides==7.7.0
#  + posthog==3.25.0
#  + pydantic-settings==2.9.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + python-dotenv==1.1.0
#  + pytrec-eval-terrier==0.5.7
#  + starlette==0.45.3
#  + typing-inspect==0.9.0
#  + uvicorn==0.34.2
#  + uvloop==0.21.0
#  + watchfiles==1.0.5
#  + xxhash==3.5.0

# %%
# Import libraries for data processing, embeddings, vector store, and performance measurement
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import ndcg_score
import nltk
import re
import torch
from sentence_transformers import SentenceTransformer
from mteb import MTEB
import pandas as pd
from langchain.docstore.document import Document
from langchain.vectorstores import Chroma
import time
import psutil
import shutil

# Download NLTK resources for text processing
nltk.download('punkt')
nltk.download('stopwords')

# %%
# Define a utility function to clean text (lowercase, remove extra spaces)
def simple_clean(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Load the Excel file containing resume texts and summaries
df = pd.read_excel('/content/synthetic_resume_summaries (1).xlsx')
df.head()

# %%
# Extract texts (full resumes) and summaries
texts = df["text"].tolist()
summaries = df["summary"].tolist()
N = len(texts)

# Clean texts and summaries to standardize them
texts_clean = [simple_clean(text) for text in texts]
summaries_clean = [simple_clean(str(summary)) for summary in summaries]

# Create documents with metadata (ID) for ChromaDB to track which text corresponds to which summary
docs = [Document(page_content=text, metadata={"id": i}) for i, text in enumerate(texts_clean)]

# %%
from langchain.embeddings import SentenceTransformerEmbeddings
# Initialize the embedding model (SentenceTransformer for generating vector embeddings)
model_name = "multi-qa-mpnet-base-dot-v1"
model = SentenceTransformerEmbeddings(model_name=model_name) # Pass model_name as a keyword argument within model_kwargs
embedding_function = model  # Use the model directly as the embedding function

# %%
# Measure ingestion time: Time taken to add all documents to ChromaDB
start_time = time.time()
vectorstore = Chroma.from_documents(
    documents=docs,
    embedding=embedding_function,
    persist_directory="./chroma_db"
)
ingestion_time = time.time() - start_time
print(f"Ingestion time: {ingestion_time} seconds")
# Out:
# Ingestion time: 40.14806079864502 seconds

# %%
# Set up the retriever to fetch top-1 document for each query (can adjust k for recall@K)
retriever = vectorstore.as_retriever(search_kwargs={"k": 1})

# %%
# Initialize lists to store performance metrics
latencies = []
recalls = []

# Loop through each summary as a query to measure latency and recall
for i, query in enumerate(summaries_clean):
    # Measure latency: Time taken to retrieve documents for this query
    start_time = time.time()
    retrieved_docs = retriever.get_relevant_documents(query)
    latency = time.time() - start_time
    latencies.append(latency)

    # Check recall: If the correct document (ID=i) is retrieved
    retrieved_ids = [doc.metadata["id"] for doc in retrieved_docs]
    correct_id = i
    if correct_id in retrieved_ids:
        recalls.append(1)  # Correct document retrieved
    else:
        recalls.append(0)  # Correct document not retrieved

# Calculate recall rate: Proportion of queries where the correct document was retrieved
average_recall = sum(recalls) / len(recalls)
print(f"Average recall@1: {average_recall}")
# Out:
# <ipython-input-18-a9f8efacf03f>:9: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   retrieved_docs = retriever.get_relevant_documents(query)
# Average recall@1: 0.698

# %%
# Calculate average latency: Mean time taken per query
average_latency = sum(latencies) / len(latencies)
print(f"Average latency: {average_latency} seconds")
# Out:
# Average latency: 0.018303057670593263 seconds

# %%
# Calculate QPS: Total queries divided by total time (sequential approximation)
total_queries = len(summaries_clean)
total_time = sum(latencies)
QPS = total_queries / total_time if total_time > 0 else 0
print(f"QPS: {QPS}")
# Out:
# QPS: 54.63567989553227

# %%
# Measure memory usage: Current memory used by the process in GB
memory_usage = psutil.virtual_memory().used / (1024 ** 3)
print(f"Memory usage: {memory_usage} GB")
# Out:
# Memory usage: 2.7359390258789062 GB

# %%
# Measure disk usage: Size of the ChromaDB directory in GB
disk_usage = shutil.disk_usage('./chroma_db').used / (1024 ** 3)
print(f"Disk usage for chroma_db: {disk_usage} GB")
# Out:
# Disk usage for chroma_db: 40.26665496826172 GB
